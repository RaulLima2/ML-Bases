# %% [markdown]
# # Instalação dos pacotes

# %%
# !pip install sklearn
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# # Importação dos Pacotes

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelENcoder, OneHorEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Carregamento do Dado

# %%
# !wget

# %%
dados: pd.DataFrame = pd.read_csv('dados_compra.csv')

# %% [markdown]
# # Preparação dos Dados

# %%
X = dados.iloc[:, :-1].values
Y = dados.iloc[:, -1].values

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:,1:3])

# %%
labelenconcer_X = LabelENcoder()
X[:,0] = labelencoder_X.fit_transform(X[:,0])
ct = ColumnTransformer(["Country", OneHotEncoder(), [0]], remainder ='passthrough')
X = ct.fit_transform(X)

# %%
labelencoder_Y = LAbelEncoder()
y = labelencoder_Y.fit_transform(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)

# %% [markdown]
# # Exercícios

# %%
dados_espectativa_vida: pd.DataFrame = pd.read_csv('expectativa_vida.csv')

# %% [markdown]
# # EDA
